# %%
import pandas as pd

# %%
#IMPORT DATA

data=pd.read_csv('titanic_train.csv')
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# SELECTIONG SERIES/COLUMNS IN DATA FRAME
# 01. DATA.NAME
# 02. DATA['Name']

# WHAT IS THE DIFFERENCE BETWEEN THE TWO?
# WELL THEY BOTH DO THE EXACT SAME THING EXPECT THE SECOND ONE IS MORE ROBUST. HERE 'PassengerId'COLUMN TO 'Passenger ID', DATA.PASSANGER ID WOULD NOT WORK.

#LETS FIRST TRY OUT IT ON THE NAME FEATURE
data.Name
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
data['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
#RENAME FOR GIVEN A SPACE

data.rename(columns={'PassengerId':'Passenger Id'},inplace=True)
data.head()
# Out:
#    Passenger Id  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data['Passenger Id']
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: Passenger Id, Length: 891, dtype: int64

# %%
#index based selction
data.iloc[0, :]
# Out:
# Passenger Id                          1
# Survived                              0
# Pclass                                3
# Name            Braund, Mr. Owen Harris
# Sex                                male
# Age                                22.0
# SibSp                                 1
# Parch                                 0
# Ticket                        A/5 21171
# Fare                               7.25
# Cabin                               NaN
# Embarked                              S
# Name: 0, dtype: object

# %%
data.iloc[:,3]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
data.iloc[1:3,0]
# Out:
# 1    2
# 2    3
# Name: Passenger Id, dtype: int64

# %%
data.iloc[[0,1,2],: ]
# Out:
#    Passenger Id  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
data.iloc[-5:, :]
# Out:
#      Passenger Id  Survived  Pclass                                      Name  \
# 886           887         0       2                     Montvila, Rev. Juozas
# 887           888         1       1              Graham, Miss. Margaret Edith
# 888           889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889           890         1       1                     Behr, Mr. Karl Howell
# 890           891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
#label based selection
data.loc[0,'Name']
# Out:
# 'Braund, Mr. Owen Harris'

# %%
data.loc[:4,['Name','Sex','Age']]
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0

# %%
#condiotiona statement
data.loc[data['Age']==50, :]
# Out:
#      Passenger Id  Survived  Pclass  \
# 177           178         0       1
# 259           260         1       2
# 299           300         1       1
# 434           435         0       1
# 458           459         1       2
# 482           483         0       3
# 526           527         1       2
# 544           545         0       1
# 660           661         1       1
# 723           724         0       2
#
#                                                 Name     Sex   Age  SibSp  \
# 177                       Isham, Miss. Ann Elizabeth  female  50.0      0
# 259                      Parrish, Mrs. (Lutie Davis)  female  50.0      0
# 299  Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0      0
# 434                        Silvey, Mr. William Baird    male  50.0      1
# 458                              Toomey, Miss. Ellen  female  50.0      0
# 482                         Rouse, Mr. Richard Henry    male  50.0      0
# ...

# %%
data.loc[(data['Age']==50)& (data['Sex']== 'female'), :]
# Out:
#      Passenger Id  Survived  Pclass  \
# 177           178         0       1
# 259           260         1       2
# 299           300         1       1
# 458           459         1       2
# 526           527         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 177                       Isham, Miss. Ann Elizabeth  female  50.0      0
# 259                      Parrish, Mrs. (Lutie Davis)  female  50.0      0
# 299  Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0      0
# 458                              Toomey, Miss. Ellen  female  50.0      0
# 526                             Ridsdale, Miss. Lucy  female  50.0      0
#
#      Parch        Ticket      Fare    Cabin Embarked
# 177      0      PC 17595   28.7125      C49        C
# 259      1        230433   26.0000      NaN        S
# 299      1      PC 17558  247.5208  B58 B60        C
# 458      0  F.C.C. 13531   10.5000      NaN        S
# ...

# %%
data.loc[(data['Age']==50) | (data['Fare']>=200), :]
# Out:
#      Passenger Id  Survived  Pclass  \
# 27             28         0       1
# 88             89         1       1
# 118           119         0       1
# 177           178         0       1
# 258           259         1       1
# 259           260         1       2
# 299           300         1       1
# 311           312         1       1
# 341           342         1       1
# 377           378         0       1
# 380           381         1       1
# 434           435         0       1
# 438           439         0       1
# 458           459         1       2
# 482           483         0       3
# 526           527         1       2
# 527           528         0       1
# 544           545         0       1
# 557           558         0       1
# 660           661         1       1
# 679           680         1       1
# 689           690         1       1
# 700           701         1       1
# 716           717         1       1
# 723           724         0       2
# ...

# %%
#isnull is used for blank
data.loc[data['Cabin'].isnull(), :]
# Out:
#      Passenger Id  Survived  Pclass                                      Name  \
# 0               1         0       3                   Braund, Mr. Owen Harris
# 2               3         1       3                    Heikkinen, Miss. Laina
# 4               5         0       3                  Allen, Mr. William Henry
# 5               6         0       3                          Moran, Mr. James
# 7               8         0       3            Palsson, Master. Gosta Leonard
# ..            ...       ...     ...                                       ...
# 884           885         0       3                    Sutehall, Mr. Henry Jr
# 885           886         0       3      Rice, Mrs. William (Margaret Norton)
# 886           887         0       2                     Montvila, Rev. Juozas
# 888           889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890           891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
#isin for True and False
data.loc[data['Embarked'].isin(['C','Q']), :]
# Out:
#      Passenger Id  Survived  Pclass  \
# 1               2         1       1
# 5               6         0       3
# 9              10         1       2
# 16             17         0       3
# 19             20         1       3
# ..            ...       ...     ...
# 875           876         1       3
# 879           880         1       1
# 885           886         0       3
# 889           890         1       1
# 890           891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 5                                     Moran, Mr. James    male   NaN      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 16                                Rice, Master. Eugene    male   2.0      4
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# ...

# %%
data.loc[(data['Embarked']=='C')|(data['Embarked']=='Q'), :]
# Out:
#      Passenger Id  Survived  Pclass  \
# 1               2         1       1
# 5               6         0       3
# 9              10         1       2
# 16             17         0       3
# 19             20         1       3
# ..            ...       ...     ...
# 875           876         1       3
# 879           880         1       1
# 885           886         0       3
# 889           890         1       1
# 890           891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 5                                     Moran, Mr. James    male   NaN      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 16                                Rice, Master. Eugene    male   2.0      4
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# ...
