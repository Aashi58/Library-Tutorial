# %%
#PANDAS LIBERARY
import pandas as pd
#read data via 'pd.read_csv'
#use the appropriate read function for different file formats

train=pd.read_csv('titanic_train.csv')
test=pd.read_csv('titanic_test.csv')
#'head' shows the first five rows of the dataframe by default but you can
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# 'tail' shows the bottom five rows by default
train.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# 'shape' function tells us how many rows and columns exist in a dataframe
train.shape
# Out:
# (891, 12)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#number entries

test_score=pd.DataFrame({'student_id':[154,973,645],'science':[50,75,31],'geography':[88,100,66],'math':[72,86,94]})
test_score
# Out:
#    student_id  science  geography  math
# 0         154       50         88    72
# 1         973       75        100    86
# 2         645       31         66    94

# %%
#text entries

survey=pd.DataFrame({'james':['i like it','it could use a bit more salt'],'emily':['it is too sweet','yum!']})
survey
# Out:
#                           james            emily
# 0                     i like it  it is too sweet
# 1  it could use a bit more salt             yum!

# %%
#index
test_score=test_score.set_index('student_id')
test_score
# Out:
#             science  geography  math
# student_id
# 154              50         88    72
# 973              75        100    86
# 645              31         66    94

# %%
survey=pd.DataFrame({'james':['i like it','it could use a bit more salt'],'emily':['it is too sweet','yum!']},index=['product A','product B'])
survey
# Out:
#                                   james            emily
# product A                     i like it  it is too sweet
# product B  it could use a bit more salt             yum!

# %%
#reset index
# Try playing around with 'drop' and 'inplace' and see what they do

survey.reset_index(drop=True,inplace=True)

# %%
survey
# Out:
#                           james            emily
# 0                     i like it  it is too sweet
# 1  it could use a bit more salt             yum!

# %%
# Suppose we want to change the names of the first two columns

test_score.rename(columns={'geography':'physics','science':'arts'},inplace=True)
test_score
# Out:
#             arts  physics  math
# student_id
# 154           50       88    72
# 973           75      100    86
# 645           31       66    94

# %%
# Drop the 'Math' column
#dropping columns and rows
test_score.drop(columns='math',inplace=True)
test_score
# Out:
#             arts  physics
# student_id
# 154           50       88
# 973           75      100
# 645           31       66

# %%
# Drop row with student_ID 973
# We can make this more robust once we learn the 'loc' function in the coming weeks

test_score.drop(973,inplace=True)
test_score
# Out:
#             arts  physics
# student_id
# 154           50       88
# 645           31       66

# %%
# Create a new column for history subject

test_score['history']=[79,70]
test_score
# Out:
#             arts  physics  history
# student_id
# 154           50       88       79
# 645           31       66       70

# %%
#series
#There are two core objects in pandas, one is dataframe which we have already gone through, the other is called a series.

#Dataframe, as we have seen, looks like a data table. A series on the other hand is a sequence of data values or sometimes called a list.

pd.Series([1,2,3,4,5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# iris,hive,cancer,tips
profit=pd.Series([75,80,66],index=['2018 profit','2019 profit','2020 profit'])
profit
# Out:
# 2018 profit    75
# 2019 profit    80
# 2020 profit    66
# dtype: int64

# %%
#Using this same logic, we can form a dataframe using a list of list i.e. a combination of series. Let's see how we can do that.

customer_Sale=pd.DataFrame([[317, 'melbourne','80'],[887, 'new york','91'],[225,'london','50']],columns=['customer_id','city','sales'])
customer_Sale
# Out:
#    customer_id       city sales
# 0          317  melbourne    80
# 1          887   new york    91
# 2          225     london    50

# %%
# READ WRITE OPERATION
d1=pd.read_csv("ex1.csv")
d1
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
# HOW TO READ TSV FILES

draft2=pd.read_table('test.tsv')
draft2
# Out:
#      a     b       c        d       e   f
# 0  meg  qual   benga      job  sweden NaN
# 1  ash    AI  mumbai  startup      uk NaN

# %%
df=pd.read_csv("test.tsv",sep="\t")
df
# Out:
#      a     b       c        d       e   f
# 0  meg  qual   benga      job  sweden NaN
# 1  ash    AI  mumbai  startup      uk NaN

# %%
draft3=pd.read_table("/content/ex3.csv")
draft3
# Out:
#                A         B         C
# 0  aaa -0.264438 -1.026059 -0.619500
# 1  bbb  0.927272  0.302904 -0.032399
# 2  ccc -0.264273 -0.386314 -0.217601
# 3  ddd -0.871858 -0.348382  1.100491

# %%
df3=pd.read_csv("ex1.csv",header=None,names=['names','age','height','weight','academic'])
df3
# Out:
#   names age height weight academic
# 0     a   b      c      d  message
# 1     1   2      3      4    hello
# 2     5   6      7      8    world
# 3     9  10     11     12      foo
